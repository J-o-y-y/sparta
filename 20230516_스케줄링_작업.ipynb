# %% [markdown]
# <a href="https://colab.research.google.com/github/J-o-y-y/sparta/blob/main/20230516_%EC%8A%A4%EC%BC%80%EC%A4%84%EB%A7%81_%EC%9E%91%EC%97%85.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 파이썬으로 메일 발송 코드를 작성했는데, 주기적으로 메일을 보내도록 스케쥴러를 생성하고 싶어. 해당 예시 코드를 알려줄 수 있어?

# %%
pip install schedule

# %%
import smtplib
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
import pandas as pd
import schedule
import time

def send_email():
    # Excel 파일에서 데이터 읽어오기
    df = pd.read_excel('customer_data_test.xlsx', sheet_name='test_name_email')

    # SMTP 서버 설정
    smtp_server = 'smtp.example.com'  # SMTP 서버 주소를 변경해주세요.
    smtp_port = 587  # SMTP 서버 포트를 변경해주세요.

    # 이메일 계정 정보
    username = 'your-email@example.com'  # 발신자 이메일 주소를 변경해주세요.
    password = 'your-password'  # 발신자 이메일 비밀번호를 변경해주세요.

    # SMTP 서버 연결
    server = smtplib.SMTP(smtp_server, smtp_port)
    server.starttls()
    server.login(username, password)

    # 각 고객에게 이메일 보내기
    for i in range(len(df)):
        msg = MIMEMultipart()
        msg['From'] = username
        msg['To'] = df['email'][i]  # 이메일 컬럼의 이름을 변경해주세요.
        msg['Subject'] = "Enjoy More Savings with Salemale's New Event!"

        # 이메일 본문
        body = f"""
        Dear {df['name'][i]},

        We are excited to announce that Salemale is launching a new event just for you!

        From now on, for every 5 purchases you make on our app, we're offering an additional 10% discount as a thank you for your continued support.

        But that's not all! We have various events like login rewards, total purchase rewards, and more. Check out our event tab regularly to not miss out on these great benefits.

        Enjoy your shopping experience with Salemale, and thank you once again for being a part of our community.

        Warm regards,
        The Salemale Team
        """

        msg.attach(MIMEText(body, 'plain'))
        server.send_message(msg)

    # SMTP 서버 연결 종료
    server.quit()

# 매일 오전 9시에 send_email 함수 실행
schedule.every().day.at("09:00").do(send_email)

# 무한 루프를 통해 스케줄러 실행 유지
while True:
    schedule.run_pending()
    time.sleep(1)

# %% [markdown]
# 아래 코드가 메일 전송 코드인데 이걸 너가 위에서 알려준 코드에 합칠 수 있어?
#
# import openpyxl
# import smtplib
# from email.mime.text import MIMEText
# from email.mime.multipart import MIMEMultipart
#
# # Gmail SMTP 서버 설정
# smtp_server = 'smtp.gmail.com'
# smtp_port = 587
# smtp_username = 'test@gmail.com'
# smtp_password = 'app_password'
#
# # Excel 파일에서 이름과 이메일 추출
# wb = openpyxl.load_workbook('customer_data_test.xlsx')
# ws = wb['test_name_email']
#
# name_list = []
# email_list = []
#
# for row in ws.iter_rows(min_row=2, values_only=True):
#     name = row[0]
#     email = row[1]
#     name_list.append(name)
#     email_list.append(email)
#
# # Gmail 서버 연결
# with smtplib.SMTP(smtp_server, smtp_port) as smtp:
#     smtp.starttls()
#     smtp.login(smtp_username, smtp_password)
#
#     for name, email in zip(name_list, email_list):
#         # 메일 제목, 본문 내용 작성
#         mail_subject = f'[{name}] 자그마한 선물을 받으세요!'
#         mail_body = f'안녕하세요 {name}님,\n\n저희 앱을 이용해주셔서 감사합니다. {name}님이 우리 앱에 10번 이상 로그인하시면 자그마한 선물을 드립니다! 하루에 최대 1번 로그인 가능합니다. 많은 이용 부탁드립니다.\n\n감사합니다.\n\n- salemale 팀'
#
#         # 메일 생성
#         message = MIMEMultipart()
#         message['From'] = smtp_username
#         message['To'] = email
#         message['Subject'] = mail_subject
#
#         # 메일 본문 추가
#         message.attach(MIMEText(mail_body))
#
#         # 메일 전송
#         smtp.send_message(message)

# %% [markdown]
# 주어진 메일 전송 코드를 schedule 라이브러리를 사용하여 매일 오전 9시에 메일을 보내도록 스케줄링하는 코드와 합칠 수 있습니다. 아래는 그 예시입니다.

# %%
import openpyxl
import smtplib
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart
import schedule
import time

# Gmail SMTP 서버 설정
smtp_server = 'smtp.gmail.com'
smtp_port = 587
smtp_username = 'test@gmail.com'
smtp_password = 'app_password'

def send_email():
    # Excel 파일에서 이름과 이메일 추출
    wb = openpyxl.load_workbook('customer_data_test.xlsx')
    ws = wb['test_name_email']

    name_list = []
    email_list = []

    for row in ws.iter_rows(min_row=2, values_only=True):
        name = row[0]
        email = row[1]
        name_list.append(name)
        email_list.append(email)

    # Gmail 서버 연결
    with smtplib.SMTP(smtp_server, smtp_port) as smtp:
        smtp.starttls()
        smtp.login(smtp_username, smtp_password)

        for name, email in zip(name_list, email_list):
            # 메일 제목, 본문 내용 작성
            mail_subject = f'[{name}] 자그마한 선물을 받으세요!'
            mail_body = f'안녕하세요 {name}님,\n\n저희 앱을 이용해주셔서 감사합니다. {name}님이 우리 앱에 10번 이상 로그인하시면 자그마한 선물을 드립니다! 하루에 최대 1번 로그인 가능합니다. 많은 이용 부탁드립니다.\n\n감사합니다.\n\n- salemale 팀'

            # 메일 생성
            message = MIMEMultipart()
            message['From'] = smtp_username
            message['To'] = email
            message['Subject'] = mail_subject

            # 메일 본문 추가
            message.attach(MIMEText(mail_body))

            # 메일 전송

# %% [markdown]
# 1분마다 보내기, every(1)
# 1시간마다 보내기, every(60)

# %%
import openpyxl
import smtplib
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart
import schedule
import time

def send_email():
    # Gmail SMTP 서버 설정
    smtp_server = 'smtp.gmail.com'
    smtp_port = 587
    smtp_username = 'test@gmail.com'
    smtp_password = 'app_password'

    # Excel 파일에서 이름과 이메일 추출
    wb = openpyxl.load_workbook('customer_data_test.xlsx')
    ws = wb['test_name_email']

    name_list = []
    email_list = []

    for row in ws.iter_rows(min_row=2, values_only=True):
        name = row[0]
        email = row[1]
        name_list.append(name)
        email_list.append(email)

    # Gmail 서버 연결
    with smtplib.SMTP(smtp_server, smtp_port) as smtp:
        smtp.starttls()
        smtp.login(smtp_username, smtp_password)

        for name, email in zip(name_list, email_list):
            # 메일 제목, 본문 내용 작성
            mail_subject = f'[{name}] 자그마한 선물을 받으세요!'
            mail_body = f'안녕하세요 {name}님,\n\n저희 앱을 이용해주셔서 감사합니다. {name}님이 우리 앱에 10번 이상 로그인하시면 자그마한 선물을 드립니다! 하루에 최대 1번 로그인 가능합니다. 많은 이용 부탁드립니다.\n\n감사합니다.\n\n- salemale 팀'

            # 메일 생성
            message = MIMEMultipart()
            message['From'] = smtp_username
            message['To'] = email
            message['Subject'] = mail_subject

            # 메일 본문 추가
            message.attach(MIMEText(mail_body))

            # 메일 전송
            smtp.send_message(message)

# 스케쥴러 설정
schedule.every(1).minutes.do(send_email)

while True:
    schedule.run_pending()
    time.sleep(1)

# %%
import openpyxl
import smtplib
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart
import schedule
import time

def send_email():
    # Gmail SMTP 서버 설정
    smtp_server = 'smtp.gmail.com'
    smtp_port = 587
    smtp_username = 'test@gmail.com'
    smtp_password = 'app_password'

    # Excel 파일에서 이름과 이메일 추출
    wb = openpyxl.load_workbook('customer_data_test.xlsx')
    ws = wb['test_name_email']

    name_list = []
    email_list = []

    for row in ws.iter_rows(min_row=2, values_only=True):
        name = row[0]
        email = row[1]
        name_list.append(name)
        email_list.append(email)

    # Gmail 서버 연결
    with smtplib.SMTP(smtp_server, smtp_port) as smtp:
        smtp.starttls()
        smtp.login(smtp_username, smtp_password)

        for name, email in zip(name_list, email_list):
            # 메일 제목, 본문 내용 작성
            mail_subject = f'[{name}] 자그마한 선물을 받으세요!'
            mail_body = f'안녕하세요 {name}님,\n\n저희 앱을 이용해주셔서 감사합니다. {name}님이 우리 앱에 10번 이상 로그인하시면 자그마한 선물을 드립니다! 하루에 최대 1번 로그인 가능합니다. 많은 이용 부탁드립니다.\n\n감사합니다.\n\n- salemale 팀'

            # 메일 생성
            message = MIMEMultipart()
            message['From'] = smtp_username
            message['To'] = email
            message['Subject'] = mail_subject

            # 메일 본문 추가
            message.attach(MIMEText(mail_body))

            # 메일 전송
            smtp.send_message(message)

# 스케쥴러 설정
schedule.every(60).minutes.do(send_email)

while True:
    schedule.run_pending()
    time.sleep(1)

# %% [markdown]
# 파이썬으로 메일 발송 코드를 작성했는데, 매주 특정 요일과 시간마다 메일을 보내도록 스케쥴러를 생성하고 싶어. 해당 예시 코드를 알려줄 수 있어?

# %%
import openpyxl
import smtplib
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart
import schedule
import time

# Gmail SMTP 서버 설정
smtp_server = 'smtp.gmail.com'
smtp_port = 587
smtp_username = 'test@gmail.com'
smtp_password = 'app_password'

def send_email():
    # Excel 파일에서 이름과 이메일 추출
    wb = openpyxl.load_workbook('customer_data_test.xlsx')
    ws = wb['test_name_email']

    name_list = []
    email_list = []

    for row in ws.iter_rows(min_row=2, values_only=True):
        name = row[0]
        email = row[1]
        name_list.append(name)
        email_list.append(email)

    # Gmail 서버 연결
    with smtplib.SMTP(smtp_server, smtp_port) as smtp:
        smtp.starttls()
        smtp.login(smtp_username, smtp_password)

        for name, email in zip(name_list, email_list):
            # 메일 제목, 본문 내용 작성
            mail_subject = f'[{name}] 자그마한 선물을 받으세요!'
            mail_body = f'안녕하세요 {name}님,\n\n저희 앱을 이용해주셔서 감사합니다. {name}님이 우리 앱에 10번 이상 로그인하시면 자그마한 선물을 드립니다! 하루에 최대 1번 로그인 가능합니다. 많은 이용 부탁드립니다.\n\n감사합니다.\n\n- salemale 팀'

            # 메일 생성
            message = MIMEMultipart()
            message['From'] = smtp_username
            message['To'] = email
            message['Subject'] = mail_subject

            # 메일 본문 추가
            message.attach(MIMEText(mail_body))

            # 메일 전송
            smtp.send_message(message)

# 매주 월요일 오전 9시에 send_email 함수 실행
schedule.every().monday.at("09:00").do(send_email)

# 무한 루프를 통해 스케줄러 실행 유지
while True:
    schedule.run_pending()
    time.sleep(1)

# %%
from openpyxl import load_workbook
import smtplib
from email.mime.text import MIMEText
import datetime as dt
import pytz
import schedule
import time

def send_emails():
    # 엑셀 파일 로드
    workbook = load_workbook("customer_data.xlsx")
    worksheet = workbook["test_customer_data"]

    # 이메일 전송을 위한 정보 입력
    sender_email = "email@gmail.com" #여러분들의 실사용 이메일 주소
    sender_password = "app_password" #생성한 앱 비밀번호

    # 고객 정보 추출 및 메일 전송
    for row in worksheet.iter_rows(min_row=2, values_only=True):
        name, email = row
        # 메일 내용
        mail_body = f"""\
        안녕하세요, {name}님!

        저희 앱 salemale에서 새로운 이벤트를 진행하고 있습니다! 이번에는 5번 구매 시 10% 추가 할인을 진행하고 있어요. 이 기회를 놓치지 마시고, 지금 바로 앱을 이용해주세요!\n\n또한, 저희 앱에서는 로그인 이벤트, 총 누적 금액 이벤트, 구매 횟수 이벤트 등 다양한 이벤트를 진행하고 있습니다. 이벤트 탭에서 주기적으로 확인하시면 더 많은 혜택을 받으실 수 있습니다.

        감사합니다!

        salemale 드림"""
        message = MIMEText(mail_body)
        # 메일 제목
        mail_subject = f"{name}님, 새로운 이벤트 안내 및 이벤트 탭 오픈 안내드립니다!"
        message["Subject"] = mail_subject
        message["From"] = sender_email
        message["To"] = email

        with smtplib.SMTP_SSL("smtp.gmail.com", 465) as server:
            server.login(sender_email, sender_password)
            server.sendmail(sender_email, email, message.as_string())

    print("메일 전송 완료")

# 대한민국 서울 시간대 설정
seoul_timezone = pytz.timezone('Asia/Seoul')

# 스케쥴러 설정
schedule.every().monday.at('10:00').astimezone(seoul_timezone).do(send_email)

while True:
    # 스케줄러가 실행될 시간이 되면 send_emails() 함수를 실행합니다.
    schedule.run_pending()
    time.sleep(1)

# %%
import openpyxl
import smtplib
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart
import schedule
import time
import pytz
from datetime import datetime

def send_email():
    # Gmail SMTP 서버 설정
    smtp_server = 'smtp.gmail.com'
    smtp_port = 587
    smtp_username = 'your_email@gmail.com'
    smtp_password = 'your_app_password'

    # Excel 파일에서 이름과 이메일 추출
    wb = openpyxl.load_workbook('customer_data_test.xlsx')
    ws = wb['test_name_email']

    name_list = []
    email_list = []

    for row in ws.iter_rows(min_row=2, values_only=True):
        name = row[0]
        email = row[1]
        name_list.append(name)
        email_list.append(email)

    # Gmail 서버 연결
    with smtplib.SMTP(smtp_server, smtp_port) as smtp:
        smtp.starttls()
        smtp.login(smtp_username, smtp_password)

        for name, email in zip(name_list, email_list):
            # 메일 제목, 본문 내용 작성
            mail_subject = f'[{name}] 자그마한 선물을 받으세요!'
            mail_body = f'안녕하세요 {name}님,\n\n저희 앱을 이용해주셔서 감사합니다. {name}님이 우리 앱에 10번 이상 로그인하시면 자그마한 선물을 드립니다! 하루에 최대 1번 로그인 가능합니다. 많은 이용 부탁드립니다.\n\n감사합니다.\n\n- salemale 팀'

            # 메일 생성
            message = MIMEMultipart()
            message['From'] = smtp_username
            message['To'] = email
            message['Subject'] = mail_subject

            # 메일 본문 추가
            message.attach(MIMEText(mail_body))

            # 메일 전송
            smtp.send_message(message)

# 서울 타임존 설정
seoul_timezone = pytz.timezone('Asia/Seoul')

# 스케쥴러 설정
schedule.every().friday.at('20:44').replace(tzinfo=seoul_timezone).do(send_email)

while True:
    schedule.run_pending()
    time.sleep(1)
